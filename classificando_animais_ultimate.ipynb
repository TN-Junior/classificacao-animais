# %% [markdown]
# # PARTE 1 - TREINANDO MODELOS

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !gdown 1Nf9PhQBHEoc_WZwiUIAPmx7Dqw09A7Ov
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Nf9PhQBHEoc_WZwiUIAPmx7Dqw09A7Ov
# From (redirected): https://drive.google.com/uc?id=1Nf9PhQBHEoc_WZwiUIAPmx7Dqw09A7Ov&confirm=t&uuid=3843754a-3599-48cd-a345-0f1b1f88d99d
# To: /content/dataset.zip
# 100% 920M/920M [00:19<00:00, 47.5MB/s]

# %%
# !unzip dataset.zip

# %%
caminho_pasta = 'dataset/'

# %%
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
train_generator = datagen.flow_from_directory(
    caminho_pasta,
    target_size=(224, 224),
    batch_size=20,
    class_mode='categorical',
    subset='training')
# Out:
# Found 1564 images belonging to 4 classes.

# %%
validation_generator = datagen.flow_from_directory(
    caminho_pasta,
    target_size=(224, 224),
    batch_size=20,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 389 images belonging to 4 classes.

# %%
inputs = Input(shape=(224, 224, 3))

# %%
x = Conv2D(64, (3, 3), activation='relu')(inputs)
x = MaxPooling2D(2, 2)(x)

# %%
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D(2, 2)(x)

# %%
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D(2, 2)(x)

# %%
x = Flatten()(x)
x = Dense(512, activation='relu')(x)

# %%
x = Dense(256, activation='relu')(x)

# %%
outputs = Dense(4, activation='softmax')(x)

# %%
model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=50
)
# Out:
# Epoch 1/2
#  2/78 [..............................] - ETA: 8:37 - loss: 2.2567 - accuracy: 0.1750
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 78/78 [==============================] - 520s 7s/step - loss: 1.2454 - accuracy: 0.4236 - val_loss: 1.0387 - val_accuracy: 0.4737
# Epoch 2/2
# 78/78 [==============================] - 510s 7s/step - loss: 1.0284 - accuracy: 0.5518 - val_loss: 0.8841 - val_accuracy: 0.6237

# %% [markdown]
# Epoch 1/50
#  5/77 [>.............................] - ETA: 35s - loss: 3.3462 - accuracy: 0.2800/usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 77/77 [==============================] - 92s 1s/step - loss: 1.3922 - accuracy: 0.3902 - val_loss: 1.1799 - val_accuracy: 0.4105
# Epoch 2/50
# 77/77 [==============================] - 79s 1s/step - loss: 1.1087 - accuracy: 0.4919 - val_loss: 1.0445 - val_accuracy: 0.5474
# Epoch 3/50
# 77/77 [==============================] - 87s 1s/step - loss: 0.9580 - accuracy: 0.5902 - val_loss: 0.9320 - val_accuracy: 0.6263
# Epoch 4/50
# 77/77 [==============================] - 89s 1s/step - loss: 0.8079 - accuracy: 0.6769 - val_loss: 0.8768 - val_accuracy: 0.6974
# Epoch 5/50
# 77/77 [==============================] - 89s 1s/step - loss: 0.6458 - accuracy: 0.7577 - val_loss: 1.2455 - val_accuracy: 0.4737
# Epoch 6/50
# 77/77 [==============================] - 87s 1s/step - loss: 0.4471 - accuracy: 0.8397 - val_loss: 1.1704 - val_accuracy: 0.6184
# Epoch 7/50
# Epoch 45/50
# 77/77 [==============================] - 89s 1s/step - loss: 1.1467e-05 - accuracy: 1.0000 - val_loss: 4.4734 - val_accuracy: 0.6105
# Epoch 46/50
# 77/77 [==============================] - 81s 1s/step - loss: 9.2584e-06 - accuracy: 1.0000 - val_loss: 4.6848 - val_accuracy: 0.6158
# Epoch 47/50
# 77/77 [==============================] - 88s 1s/step - loss: 7.7207e-06 - accuracy: 1.0000 - val_loss: 4.8832 - val_accuracy: 0.6026
# Epoch 48/50
# 77/77 [==============================] - 89s 1s/step - loss: 6.5558e-06 - accuracy: 1.0000 - val_loss: 4.8578 - val_accuracy: 0.6079
# Epoch 49/50
# 77/77 [==============================] - 81s 1s/step - loss: 5.6572e-06 - accuracy: 1.0000 - val_loss: 4.9410 - val_accuracy: 0.6079
# Epoch 50/50
# 77/77 [==============================] - 88s 1s/step - loss: 4.9145e-06 - accuracy: 1.0000 - val_loss: 4.9369 - val_accuracy: 0.6132
# <keras.src.callbacks.History at 0x7edb7270bbb0>

# %%
val_loss, val_accuracy = model.evaluate(
    validation_generator,
    steps=validation_generator.samples // validation_generator.batch_size
)

print(f"Perda de validação: {val_loss:.2f}")
print(f"Precisão de validação: {val_accuracy * 100:.2f}%")
# Out:
# 19/19 [==============================] - 36s 2s/step - loss: 0.8741 - accuracy: 0.6316
# Perda de validação: 0.87
# Precisão de validação: 63.16%

# %% [markdown]
# 19/19 [==============================] - 12s 610ms/step - loss: 4.8001 - accuracy: 0.6184
# Perda de validação: 4.80
# Precisão de validação: 61.84%

# %% [markdown]
# #PARTE 1.1 - TREINANDO MODELOS

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !gdown 1Nf9PhQBHEoc_WZwiUIAPmx7Dqw09A7Ov
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Nf9PhQBHEoc_WZwiUIAPmx7Dqw09A7Ov
# From (redirected): https://drive.google.com/uc?id=1Nf9PhQBHEoc_WZwiUIAPmx7Dqw09A7Ov&confirm=t&uuid=1e325afc-3fe3-4de0-8ea9-138d76bd6a75
# To: /content/dataset.zip
# 100% 920M/920M [00:05<00:00, 155MB/s]

# %%
# !unzip dataset.zip
# Out:
# Archive:  dataset.zip
#    creating: dataset/bird/
#   inflating: dataset/bird/03982423.jpg
#   inflating: dataset/bird/83088806.jpg
#   inflating: dataset/bird/a1364128.jpg
#   inflating: dataset/bird/iZkDQMqeQlqhoCIywoFv_6005485056_c8622e0824_o.jpg
#   inflating: dataset/bird/iZkDQMqeQlqhoCIywoFv_6005485056_c8622e0824_o2.jpg
#   inflating: dataset/bird/photo-1421992803150-58062de7c748.jpg
#   inflating: dataset/bird/photo-1423176281849-2d0f865692cc.jpg
#   inflating: dataset/bird/photo-1428448816382-91cedd04e38a.jpg
#   inflating: dataset/bird/photo-1428572509712-cb9a529e81d7.jpg
#   inflating: dataset/bird/photo-1428708161673-06f323c1df8f.jpg
#   inflating: dataset/bird/photo-1428883476845-960f11b9dd8f.jpg
#   inflating: dataset/bird/photo-1433351120803-a29aeee7d1e7.jpg
#   inflating: dataset/bird/photo-1434564532742-8d6f87295125.jpg
#   inflating: dataset/bird/photo-1440588088625-01f0d8817535.jpg
#   inflating: dataset/bird/photo-1441106830165-0a7b32f5a342.jpg
# ...

# %%
caminho_pasta = 'dataset/'

# %%
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# %%
train_generator = datagen.flow_from_directory(
    caminho_pasta,
    target_size=(224, 224),
    batch_size=20,
    class_mode='categorical',
    subset='training')
# Out:
# Found 1564 images belonging to 4 classes.

# %%
validation_generator = datagen.flow_from_directory(
    caminho_pasta,
    target_size=(224, 224),
    batch_size=20,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 389 images belonging to 4 classes.

# %%
inputs = Input(shape=(224, 224, 3))

# %%
x = Conv2D(32, (3, 3), activation='relu')(inputs)
x = MaxPooling2D(2, 2)(x)

# %%
x = Conv2D(64, (3, 3), activation='relu')(inputs)
x = MaxPooling2D(2, 2)(x)

# %%
x = Conv2D(64, (3, 3), activation='relu')(inputs)
x = MaxPooling2D(2, 2)(x)

# %%
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D(2, 2)(x)

# %%
x = Conv2D(128, (3, 3), activation='relu')(x)
x = MaxPooling2D(2, 2)(x)

# %%
x = Flatten()(x)
x = Dense(512, activation='relu')(x)

# %%
x = Dense(256, activation='relu')(x)

# %%
outputs = Dense(4, activation='softmax')(x)

# %%
model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=50
)
# Out:
# Epoch 1/50
#  2/78 [..............................] - ETA: 7:06 - loss: 4.3494 - accuracy: 0.2250
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 78/78 [==============================] - 408s 5s/step - loss: 1.3087 - accuracy: 0.4210 - val_loss: 1.0410 - val_accuracy: 0.5500
# Epoch 2/50
# 78/78 [==============================] - 390s 5s/step - loss: 0.9394 - accuracy: 0.6172 - val_loss: 0.7615 - val_accuracy: 0.6789
# Epoch 3/50
# 78/78 [==============================] - 381s 5s/step - loss: 0.6145 - accuracy: 0.7610 - val_loss: 0.6621 - val_accuracy: 0.7395
# Epoch 4/50
# 78/78 [==============================] - 385s 5s/step - loss: 0.4280 - accuracy: 0.8472 - val_loss: 0.6409 - val_accuracy: 0.7605
# Epoch 5/50
# 78/78 [==============================] - 389s 5s/step - loss: 0.2504 - accuracy: 0.9242 - val_loss: 0.8856 - val_accuracy: 0.7895
# ...

# %% [markdown]
# ACURRACY TOTAL DE 0.7737

# %%
val_loss, val_accuracy = model.evaluate(
    validation_generator,
    steps=validation_generator.samples // validation_generator.batch_size
)

print(f"Perda de validação: {val_loss:.2f}")
print(f"Precisão de validação: {val_accuracy * 100:.2f}%")

# %% [markdown]
# # PARTE 2 - SALVANDO E CARREGANDO MODELOS

# %%
from google.colab import drive
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
model.save('/content/drive/My Drive/aula/model3.h5')

# %%
loaded_model = load_model('/content/drive/My Drive/aula/model3.h5')

# %%
validation_generator.reset()
for x_batch, y_batch in validation_generator:
    image_data = x_batch[2]
    break

# %%
prediction = loaded_model.predict(np.expand_dims(image_data, axis=0))
class_names = ['bird','cat','dog','fish']
predicted_index = np.argmax(prediction[0])
predicted_class = class_names[predicted_index]
print("Predição: ", predicted_class)

plt.imshow(image.array_to_img(image_data))
plt.title(f'Predição: {predicted_class}')
plt.show()
# Out:
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7edb5018b400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 98ms/step
# Predição:  fish

# %% [markdown]
# Erro da Ia ao classificar um lagarto como peixe

# %% [markdown]
# # PARTE 3 - TRANSFER LEARNING

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras import Input

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output
x = Flatten()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
outputs = Dense(2, activation='softmax')(x)

# %%
transfer_model = Model(inputs=base_model.input, outputs=outputs)

# %%
transfer_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=50
)
# Out:
# Epoch 1/50
# 77/77 [==============================] - 91s 1s/step - loss: 2.4884e-06 - accuracy: 1.0000 - val_loss: 4.9995 - val_accuracy: 0.6211
# Epoch 2/50
# 77/77 [==============================] - 83s 1s/step - loss: 2.2739e-06 - accuracy: 1.0000 - val_loss: 5.0505 - val_accuracy: 0.6132
# Epoch 3/50
# 77/77 [==============================] - 90s 1s/step - loss: 2.0865e-06 - accuracy: 1.0000 - val_loss: 5.1314 - val_accuracy: 0.6132
# Epoch 4/50
# 77/77 [==============================] - 90s 1s/step - loss: 1.9176e-06 - accuracy: 1.0000 - val_loss: 5.1230 - val_accuracy: 0.6105
# Epoch 5/50
# 77/77 [==============================] - 82s 1s/step - loss: 1.7669e-06 - accuracy: 1.0000 - val_loss: 5.0424 - val_accuracy: 0.6079
# Epoch 6/50
# 77/77 [==============================] - 90s 1s/step - loss: 1.6283e-06 - accuracy: 1.0000 - val_loss: 5.1442 - val_accuracy: 0.6132
# Epoch 7/50
# ...

# %% [markdown]
# ACURRACY TOTAL  EM 50 EPOCHS DE 0.6158

# %%
validation_generator.reset()
for x_batch, y_batch in validation_generator:
    image_data = x_batch[4]
    break

# %%
prediction = transfer_model.predict(np.expand_dims(image_data, axis=0))
class_names = ['bird','cat','dog','fish']
predicted_index = np.argmax(prediction[0])
predicted_class = class_names[predicted_index]
print("Predição: ", predicted_class)

plt.imshow(image.array_to_img(image_data))
plt.title(f'Predição: {predicted_class}')
plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# Predição:  bird

# %% [markdown]
# Erro da Ia ao classificar um lagarto como passaro

# %% [markdown]
# # PARTE 3.1 - TRANSFER LEARNING

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras import Input

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_tensor=Input(shape=(224, 224, 3)))

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
x = base_model.output

# Flatten layer
x = Flatten()(x)

# Dense layer with 256 units and ReLU activation
x = Dense(256, activation='relu')(x)

# Dropout layer with dropout rate of 0.5
x = Dropout(0.5)(x)

# Output layer with 2 units for binary classification and softmax activation
outputs = Dense(2, activation='softmax')(x)

# Define model
model = Model(inputs=base_model.input, outputs=outputs)

# %%
transfer_model = Model(inputs=base_model.input, outputs=outputs)

# %%
transfer_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=50
)

# %%
validation_generator.reset()
for x_batch, y_batch in validation_generator:
    image_data = x_batch[4]
    break

# %%
prediction = transfer_model.predict(np.expand_dims(image_data, axis=0))
class_names = ['bird','cat','dog','fish']
predicted_index = np.argmax(prediction[0])
predicted_class = class_names[predicted_index]
print("Predição: ", predicted_class)

plt.imshow(image.array_to_img(image_data))
plt.title(f'Predição: {predicted_class}')
plt.show()
